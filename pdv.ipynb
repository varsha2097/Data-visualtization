# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv("Accident_Cities.csv")

# %%
df2=pd.read_csv("Accident_States.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 30 columns):
# Name of City                              51 non-null object
# Total number of Fatal Accidents - 2011    38 non-null float64
# All Accidents - 2011                      39 non-null float64
# Persons Killed - 2011                     39 non-null float64
# Persons Injured - 2011                    39 non-null float64
# Total number of Fatal Accidents - 2012    50 non-null float64
# All Accidents - 2012                      50 non-null float64
# Persons Killed - 2012                     50 non-null float64
# Persons Injured - 2012                    50 non-null float64
# Fatal Accidents - 2013                    50 non-null float64
# Total Accidents - 2013                    50 non-null float64
# Killed - 2013                             50 non-null float64
# Injured - 2013                            50 non-null float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 23 columns):
# Unnamed: 0                            37 non-null object
# Unnamed: 1                            36 non-null object
# Unnamed: 2                            36 non-null object
# Unnamed: 3                            36 non-null object
# Unnamed: 4                            36 non-null object
# KIlled due to Over Speed              36 non-null float64
# Unnamed: 6                            36 non-null float64
# Unnamed: 7                            36 non-null float64
# Unnamed: 8                            35 non-null float64
# Unnamed: 9                            34 non-null float64
# Unnamed: 10                           35 non-null float64
# Unnamed: 11                           36 non-null float64
# Unnamed: 12                           37 non-null float64
# Unnamed: 13                           37 non-null int64
# ...

# %%
df1=df1.applymap(lambda x: x.strip() if isinstance(x,str) else x)

# %%
d2f=df2.applymap(lambda x: x.strip() if isinstance(x,str) else x)

# %%
df1.fillna(0)
# Out:
#         Name of City  Total number of Fatal Accidents - 2011  \
# 0               Agra                                   336.0
# 1          Ahmedabad                                   222.0
# 2   Asansol-Durgapur                                   229.0
# 3         Aurangabad                                   161.0
# 4          Bengaluru                                   689.0
# 5             Bhopal                                   275.0
# 6         Coimbatore                                   253.0
# 7              Delhi                                  2007.0
# 8            Dhanbad                                    74.0
# 9          Faridabad                                   229.0
# 10         Ghaziabad                                   495.0
# 11           Gwalior                                   233.0
# 12         Hyderabad                                   428.0
# 13            Indore                                   407.0
# ...

# %%
df2.tail(10)
# Out:
#                      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 27                  Uttarakhand       1784       1656       1712       1577
# 28                Uttar Pradesh      20632      20113      15513      22155
# 29                  West Bengal      12186      15760      14962      13773
# 30  Andaman and Nicobar Islands        342        373        298        288
# 31                   Chandigarh        321        415        370        347
# 32       Dadra and Nagar Haveli         71        134        210        122
# 33                Daman and Diu         69         43         37         39
# 34                        Delhi       6936       7108       7226       6633
# 35                  Lakshadweep          3          5          0          3
# 36                   Puducherry       1732       1505       1689       1129
#
#     KIlled due to Over Speed  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
df2.fillna(0)
# Out:
#                      Unnamed: 0  \
# 0                    States/UTs
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                  Chhattisgarh
# 6                           Goa
# 7                       Gujarat
# 8                       Haryana
# 9              Himachal Pradesh
# 10            Jammu and Kashmir
# 11                    Jharkhand
# 12                    Karnataka
# 13                       Kerala
# 14               Madhya Pradesh
# 15                  Maharashtra
# 16                      Manipur
# 17                    Meghalaya
# 18                      Mizoram
# 19                     Nagaland
# 20                       Odisha
# 21                       Punjab
# 22                    Rajasthan
# 23                       Sikkim
# 24                   Tamil Nadu
# 25                    Telangana
# 26                      Tripura
# 27                  Uttarakhand
# ...

# %%
df1.head()
# Out:
#        Name of City  Total number of Fatal Accidents - 2011  \
# 0              Agra                                   336.0
# 1         Ahmedabad                                   222.0
# 2  Asansol-Durgapur                                   229.0
# 3        Aurangabad                                   161.0
# 4         Bengaluru                                   689.0
#
#    All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 0                1299.0                  632.0                  1046.0
# 1                2020.0                  227.0                  2036.0
# 2                 368.0                  230.0                   185.0
# 3                 719.0                  173.0                   744.0
# 4                6031.0                  720.0                  4952.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# ...

# %%
a=df1[["Name of City"]]
b=df1[["Persons Injured - 2011"]]
df1.sortvalues("b",ascending=False)
df1.head()

# %%
max4=df1["Greviously Injured Accidents - 2014"].max()+df1["Injured - 2014"].max()
max6=df1["Greviously Injured Accidents - 2015"].max()+df1["Injured - 2015"].max()

# %%
max1=df1["Persons Injured - 2011"].max()
max2=df1["Persons Injured - 2012"].max()
max3=df1["Injured - 2013"].max()
sum=max1+max2+max3+max4+max6

sum
# Out:
# 47864.0

# %%
sum=df1["Persons Injured - 2011"].max()+df1["Persons Injured - 2012"]+df1["Injured - 2013"]+df1["Greviously Injured Accidents - 2014"]
+df1["Injured - 2014"]+df1["Greviously Injured Accidents - 2015"]+df1["Injured - 2015"]
sum.max()
# Out:
# 21309.0

# %%
a=df1[["Name of City"]]
a
# Out:
#         Name of City
# 0               Agra
# 1          Ahmedabad
# 2   Asansol-Durgapur
# 3         Aurangabad
# 4          Bengaluru
# 5             Bhopal
# 6         Coimbatore
# 7              Delhi
# 8            Dhanbad
# 9          Faridabad
# 10         Ghaziabad
# 11           Gwalior
# 12         Hyderabad
# 13            Indore
# 14            Jaipur
# 15          Jabalpur
# 16        Jamshedpur
# 17           Jodhpur
# 18             Kochi
# 19           Kolkata
# 20            Kollam
# 21              Kota
# 22            Kannur
# 23           Lucknow
# 24          Ludhiana
# 25           Madurai
# 26        Mallapuram
# 27            Mumbai
# 28            Meerut
# 29            Nagpur
# 30             Patna
# 31              Pune
# 32            Rajkot
# 33             Surat
# 34          Srinagar
# 35          Thrissur
# 36           Vadodra
# 37          Varanasi
# 38     Visakhapatnam
# 39         Allahabad
# 40          Amritsar
# 41        Chandigarh
# ...

# %%
print(sum.max())
a=np.where(sum==sum.max())
new=df.iloc[a]
new["Name of City"]
# Out:
# 21309.0
# 7    Delhi
# Name: Name of City, dtype: object

# %%
print(sum.max())
a=np.where(sum==sum.max())
new=df.iloc[a]
new["Name of City"]
# Out:
# 47864.0
# 0    Agra
# Name: Name of City, dtype: object

# %%
acc=df[["Name of City" ,"All Accidents - 2011", "All Accidents - 2012","Total Accidents - 2013","Total Accidents - 2014","Total Accidents - 2015"]]

# %%
acc
# Out:
#         Name of City  All Accidents - 2011  All Accidents - 2012  \
# 0               Agra                1299.0                 922.0
# 1          Ahmedabad                2020.0                1850.0
# 2   Asansol-Durgapur                 368.0                 380.0
# 3         Aurangabad                 719.0                 715.0
# 4          Bengaluru                6031.0                5508.0
# 5             Bhopal                3459.0                3623.0
# 6         Coimbatore                1126.0                1128.0
# 7              Delhi                7281.0                6937.0
# 8            Dhanbad                 138.0                 144.0
# 9          Faridabad                 803.0                 711.0
# 10         Ghaziabad                1109.0                 850.0
# 11           Gwalior                2030.0                1974.0
# 12         Hyderabad                2651.0                2577.0
# ...

# %%
acc["rank"]=acc["Name of City"].rank()
# Out:
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
acc.sort_values("Name of City", inplace = True)
# Out:
# F:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
acc
# Out:
#         Name of City  All Accidents - 2011  All Accidents - 2012  \
# 0               Agra                1299.0                 922.0
# 1          Ahmedabad                2020.0                1850.0
# 39         Allahabad                   NaN                 933.0
# 40          Amritsar                   NaN                 152.0
# 2   Asansol-Durgapur                 368.0                 380.0
# 3         Aurangabad                 719.0                 715.0
# 4          Bengaluru                6031.0                5508.0
# 5             Bhopal                3459.0                3623.0
# 41        Chandigarh                   NaN                 419.0
# 42           Chennai                   NaN                9663.0
# 6         Coimbatore                1126.0                1128.0
# 7              Delhi                7281.0                6937.0
# 8            Dhanbad                 138.0                 144.0
# ...

# %%
acc = acc.sort_values(by ='Name of City' , ascending=False)
acc
# Out:
#         Name of City  All Accidents - 2011  All Accidents - 2012  \
# 50             Vizaq                   NaN                1439.0
# 38     Visakhapatnam                1548.0                   NaN
# 49    Vijaywada City                   NaN                1600.0
# 37          Varanasi                 142.0                 379.0
# 36           Vadodra                1343.0                1196.0
# 48    Tiruchirapalli                   NaN                 778.0
# 35          Thrissur                1262.0                1288.0
# 47  Thiruvanthapuram                   NaN                1933.0
# 33             Surat                1223.0                1146.0
# 34          Srinagar                 492.0                 511.0
# 32            Rajkot                1039.0                 981.0
# 46            Raipur                   NaN                2222.0
# 31              Pune                 261.0                1624.0
# ...

# %%
df=df2["KIlled due to Over Speed"]
df
# Out:
# 0     2008.0
# 1     7471.0
# 2       32.0
# 3      843.0
# 4     1008.0
# 5     1347.0
# 6      271.0
# 7     4373.0
# 8     2580.0
# 9      388.0
# 10     603.0
# 11     633.0
# 12    5678.0
# 13    2317.0
# 14    4034.0
# 15    8704.0
# 16      22.0
# 17      69.0
# 18      35.0
# 19      25.0
# 20    1330.0
# 21    1478.0
# 22    4736.0
# 23      28.0
# 24    5703.0
# 25       NaN
# 26     175.0
# 27     575.0
# 28    2803.0
# 29    1670.0
# 30      15.0
# 31      20.0
# 32      65.0
# 33       5.0
# 34       0.0
# 35       0.0
# 36     210.0
# Name: KIlled due to Over Speed, dtype: float64

# %%
df1[["Name of City","Persons Killed - 2011","Persons Killed - 2012","Killed - 2013","Killed - 2014","Killed - 2015"]]
# Out:
#         Name of City  Persons Killed - 2011  Persons Killed - 2012  \
# 0               Agra                  632.0                  427.0
# 1          Ahmedabad                  227.0                  251.0
# 2   Asansol-Durgapur                  230.0                  224.0
# 3         Aurangabad                  173.0                  192.0
# 4          Bengaluru                  720.0                  725.0
# 5             Bhopal                  299.0                  301.0
# 6         Coimbatore                  259.0                  270.0
# 7              Delhi                 2065.0                 1866.0
# 8            Dhanbad                   82.0                   54.0
# 9          Faridabad                  249.0                  247.0
# 10         Ghaziabad                  535.0                  378.0
# 11           Gwalior                  248.0                  232.0
# 12         Hyderabad                  441.0                  464.0
# ...

# %% [markdown]
# df1

# %%
x1=df1[["Name of City","Persons Killed - 2011"]].max()

# %%
x2=df1[["Name of City","Persons Killed - 2012"]].max()
x2
# Out:
# Name of City             Vizaq
# Persons Killed - 2012     1866
# dtype: object

# %%
x3=df1[["Name of City", "Killed - 2013"]].max()
x3
# Out:
# Name of City     Vizaq
# Killed - 2013     1820
# dtype: object

# %%
x4=df1[["Name of City", "Killed - 2014"]].max()
x4
# Out:
# Name of City     Vizaq
# Killed - 2014     1671
# dtype: object

# %%
x5=df1[["Name of City", "Killed - 2015"]].max()
x5
# Out:
# Name of City     Vizaq
# Killed - 2015     1622
# dtype: object

# %%
a=df1[["Name of City","Persons Killed - 2011","Persons Killed - 2012","Killed - 2013","Killed - 2014","Killed - 2015"]]

# %%
df=pd.read_csv("Accident_Cities.csv",index_col="Name of City")
first=df.loc["Delhi"]

# %%
df["injured"]=df[""]

# %%
import matplotlib.pyplot as plt
import numpy as np

objects = ['Delhi', 'Bengaluru', 'Mumbai', 'Kolkata', 'Lucknow']
x_pos = np.arange(len(objects))
performance = ['']

plt.bar(x_pos, performance)
plt.xticks(x_pos, objects)
plt.xlabel('States')
plt.ylabel('Usage')
plt.title('Accident')

plt.show()
